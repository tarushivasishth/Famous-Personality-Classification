# %%
# import requests
# import os

# API_KEY = 'AIzaSyD3mp0muKxh6-oShy-FuxgGTiOcSh7qTDI'
# SEARCH_ENGINE_ID = '902767cb88f7e42ee'

# def download_images(query, num_images=50):
#     search_url = "https://www.googleapis.com/customsearch/v1"
    
#     # Parameters for search
#     params = {
#         'q': query,
#         'searchType': 'image',
#         'key': API_KEY,
#         'cx': SEARCH_ENGINE_ID,
#         'num': 10,  # Max 10 results per request
#         'start': 1
#     }

#     images = []
#     count = 0
#     while count < num_images:
#         res = requests.get(search_url, params=params)
        
#         # Print full response to see what's happening
#         print(res.json())
        
#         if res.status_code == 200:
#             data = res.json()
            
#             # Check if 'items' exists in response
#             if 'items' in data:
#                 for item in data['items']:
#                     images.append(item['link'])
#                     count += 1
#                     if count >= num_images:
#                         break
#             else:
#                 print(f"No results found for query: {query}")
#                 break
#         else:
#             print(f"Error: {res.status_code}, {res.text}")
#             break
        
#         # Update the start index for the next batch of results
#         params['start'] += 10

#     # Download and save images
#     if images:
#         os.makedirs('./dataset/images', exist_ok=True)
#         for idx, img_url in enumerate(images):
#             try:
#                 img_data = requests.get(img_url).content
#                 with open(f'images/image_{idx+1}.jpg', 'wb') as img_file:
#                     img_file.write(img_data)
#             except Exception as e:
#                 print(f"Error downloading image {idx+1}: {e}")
    
#     print(f'{len(images)} images downloaded successfully.')

# # Example usage:
# download_images('cats', 50)

# %%
# API_KEY = 'AIzaSyD3mp0muKxh6-oShy-FuxgGTiOcSh7qTDI'
# SEARCH_ENGINE_ID = '902767cb88f7e42ee'

# %%
# import requests
# import json

# # Replace with your Custom Search API key and search engine ID
# API_KEY = 'AIzaSyD3mp0muKxh6-oShy-FuxgGTiOcSh7qTDI'
# SEARCH_ENGINE_ID = '902767cb88f7e42ee'
# query = 'APJ Abdul Kalam'
# num_images_to_fetch = 50

# # Function to fetch images from the API
# def fetch_images(query, start_index, num_images=10):
#     url = f"https://www.googleapis.com/customsearch/v1?q={query}&searchType=image&key={API_KEY}&cx={SEARCH_ENGINE_ID}&start={start_index}&num={num_images}"
#     response = requests.get(url)
#     if response.status_code == 200:
#         return response.json()
#     else:
#         print(f"Error: {response.status_code}")
#         return None

# # Fetch all images in batches of 10
# all_image_urls = []
# for start in range(1, num_images_to_fetch, 10):
#     json_data = fetch_images(query, start)
#     if json_data and 'items' in json_data:
#         image_urls = [item['link'] for item in json_data['items']]
#         all_image_urls.extend(image_urls)
#     else:
#         print("No more images found.")
#         break

# print(f"Fetched {len(all_image_urls)} image URLs.")
# Out:
# Error: 429
# No more images found.
# Fetched 0 image URLs.

# %%
# import os

# # Directory to save images
# save_dir = "dataset/virat_kohli"
# if not os.path.exists(save_dir):
#     os.makedirs(save_dir)

# # Download each image
# for i, url in enumerate(all_image_urls):
#     try:
#         response = requests.get(url)
#         if response.status_code == 200:
#             with open(os.path.join(save_dir, f"image_{i+1}.jpg"), 'wb') as f:
#                 f.write(response.content)
#             print(f"Image {i+1} downloaded successfully.")
#         else:
#             print(f"Failed to download image {i+1}.")
#     except Exception as e:
#         print(f"Error downloading image {i+1}: {e}")

# %%
# pip install Pillow

# %%
# pip install selenium

# %%
# pip install requests

# %%
# PATH = r"D:\sports_personality_classification\model"

# %%
# from selenium import webdriver
# from webdriver_manager.chrome import ChromeDriverManager

# driver = webdriver.Chrome(ChromeDriverManager().install())
# driver.get("https://www.google.com/")

# %%
# pip install --upgrade selenium

# %%
# pip install --upgrade selenium webdriver-manager

# %%
# from webdriver_manager.chrome import ChromeDriverManager

# print(ChromeDriverManager().install())

# %%
# import time
# import requests 
# import io
# import hashlib
# import os
# from selenium import webdriver

# from selenium.webdriver.common.keys import Keys


# def fetch_image_urls_util(url,driver_path):
#     images = []
#     # Open main window with URL A
#     with webdriver.Chrome(executable_path=driver_path) as wd:

#         # Switch to the new window and open URL B
#         try:
#             wd.get(url)
#         except:
#             return []

#         thumbnail_results = wd.find_elements_by_css_selector("img[class ='irc_mi']")

#         for img in thumbnail_results:
#             if img.get_attribute('src') and 'http' in img.get_attribute('src'):
#                 images.append(img.get_attribute('src'))

#     return images


# def fetch_image_urls(query:str, max_links_to_fetch:int, wd, sleep_between_interactions:int=1,driver_path= None, target_path = None, search_term = None):
    
#     target_folder = os.path.join(target_path,'_'.join(search_term.lower().split(' ')))
#     def scroll_to_end(wd):
#         wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#         time.sleep(sleep_between_interactions)    
    
#     # build the google query
#     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"

#     # load the page
#     wd.get(search_url.format(q=query))

#     image_urls = set()
#     image_count = 0
#     image_count2 = 0
#     results_start = 0
#     i = 0
#     d = {}
#     while image_count < max_links_to_fetch:
#         scroll_to_end(wd)

#         # get all image thumbnail results
#         thumbnail_results = wd.find_elements_by_css_selector("img.Q4LuWd")
#         number_results = len(thumbnail_results)
        
#         print(f"Found: {number_results} search results. Extracting links from {results_start}:{number_results}")
        
#         for img in thumbnail_results[50:number_results]:
#             # try to click every thumbnail such that we can get the real image behind it
#             try:
#                 img.click()
#                 time.sleep(sleep_between_interactions)
#             except Exception as e:
#                 print(e)
#                 continue
            
#             links = wd.find_elements_by_css_selector("a[jsname='sTFXNd']")

#             for link in links:
#                 if link.get_attribute('href') and 'http' in link.get_attribute('href'):
#                     if link.get_attribute('href') not in d:
#                         d[link.get_attribute('href')] = True
#                         getactualurl = fetch_image_urls_util(link.get_attribute('href'),driver_path)
#                     for imageurl in getactualurl:
#                         if imageurl is not None:
#                             #print(imageurl)
#                             image_urls.add(imageurl)
            
#             image_count2 = len(image_urls)
#             print(image_count2)
#             if image_count2 >= max_links_to_fetch/10:
#                 print(f"Found: {len(image_urls)} image links, saving!")
#                 try:    
#                     for elem in image_urls:
#                         persist_image(target_folder,elem)
#                 except Exception as e:
#                     print(e)
#                 image_urls = set()
#                 d = {}

#             image_count += image_count2
                
#         #image_count = len(image_urls)

#         if len(image_urls) >= max_links_to_fetch:
#             print(f"Found: {len(image_urls)} image links, done!")
#             break
#         else:
#             print("Found:", len(image_urls), "image links, looking for more ...")
#             time.sleep(30)
#             return
#             load_more_button = wd.find_element_by_css_selector(".mye4qd")
#             if load_more_button:
#                 wd.execute_script("document.querySelector('.mye4qd').click();")

#         # move the result startpoint further down
#         results_start = image_count

#     print(len(image_urls))
#     return image_urls



# def persist_image(folder_path:str,url:str):
#     try:
#         image_content = requests.get(url).content

#     except Exception as e:
#         print(f"ERROR - Could not download {url} - {e}")

#     try:
#         image_file = io.BytesIO(image_content)
#         image = Image.open(image_file).convert('RGB')
#         file_path = os.path.join(folder_path,hashlib.sha1(image_content).hexdigest()[:10] + '.jpg')
#         with open(file_path, 'wb') as f:
#             image.save(f, "JPEG", quality=85)
#         print(f"SUCCESS - saved {url} - as {file_path}")
#     except Exception as e:
#         print(f"ERROR - Could not save {url} - {e}")
        
  
    
# def search_and_download(search_term:str,driver_path:str,target_path='./datasets',number_images=50):
#     target_folder = os.path.join(target_path,'_'.join(search_term.lower().split(' ')))

#     if not os.path.exists(target_folder):
#         os.makedirs(target_folder)

#     with webdriver.Chrome(executable_path=driver_path) as wd:
#         res = fetch_image_urls(search_term, number_images, wd=wd, sleep_between_interactions=0.5,driver_path= driver_path,target_path= target_path,search_term=search_term)
#     try:    
#         for elem in res:
#             persist_image(target_folder,elem)
#     except Exception as e:
#         print(e)
        
# import time
# import requests 
# import io
# from PIL import Image, ImageDraw
# import hashlib
# import os
# from selenium import webdriver


# query = ["Serena Williams"]

# for q in query:
#     search_and_download(q,"./chromedriver.exe")

# %%
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.common.by import By  # Import By
# import requests
# import os

# # Provide the path to your ChromeDriver executable
# chrome_driver_path = "./chromedriver.exe"  # Update this with your actual path

# # Setup Selenium using the Service class
# service = Service(executable_path=chrome_driver_path)
# driver = webdriver.Chrome(service=service)

# # Navigate to the website
# driver.get('https://www.google.com/search?sca_esv=18fa2256dcc18326&sca_upv=1&rlz=1C1CHBF_enIN916IN916&sxsrf=ADLYWIJlUyRaw0sm0gFqIk43Q7k9BU0NDw:1727384117976&q=pv+sindhu&udm=2&fbs=AEQNm0CRraR4AFMOJtZDUPiZk_hDEGW7EwGJ8ltzg0fUf3C5XQ77d2-1iMSp3wdEYbyzpZPckXLsN0SSnUI7riz2SzptL-YZRKwTRF7Xifa47LncGyr7rGjLkYrnwMvuVEb7a9MvInW5r88I7Lc0nmNJqOE4vUiGS7BB3h3m_2EG1oeH6vlYpuWBpOWXOnggXIquMa6F1FY72zfWuGF9q1W5c_6AXEexig&sa=X&ved=2ahUKEwj3mvilv-GIAxUnXGwGHQ1QFMkQtKgLegQIFxAB&biw=1280&bih=551&dpr=1.5')

# # Extract image URLs using By.TAG_NAME
# images = driver.find_elements(By.TAG_NAME, 'img')
# img_urls = [img.get_attribute('src') for img in images]

# # Filter out None or invalid URLs
# img_urls = [url for url in img_urls if url and url.startswith('http')]

# # Specify the directory to save images
# save_directory = "./dataset/pv_sindhu"  # Change this to your desired directory

# # Create the directory if it doesn't exist
# os.makedirs(save_directory, exist_ok=True)

# # Download images, limited to 50
# for i, url in enumerate(img_urls[:50]):  # Limit the loop to the first 50 images
#     print(f"Downloading image {i+1} from {url}...")  # Print status
#     img_data = requests.get(url).content
#     with open(os.path.join(save_directory, f'image_{i}.jpg'), 'wb') as img_file:
#         img_file.write(img_data)
#     print(f"Image {i+1} downloaded and saved as image_{i}.jpg")  # Print success message

# driver.quit()
# Out:
# ...
# Image 1 downloaded and saved as image_0.jpg
# ...
# Image 2 downloaded and saved as image_1.jpg
# ...
# Image 3 downloaded and saved as image_2.jpg
# ...
# Image 4 downloaded and saved as image_3.jpg
# ...
# Image 5 downloaded and saved as image_4.jpg
# ...
# Image 6 downloaded and saved as image_5.jpg
# ...
# Image 7 downloaded and saved as image_6.jpg
# ...
# Image 8 downloaded and saved as image_7.jpg
# ...
# Image 9 downloaded and saved as image_8.jpg
# ...
# Image 10 downloaded and saved as image_9.jpg
# ...
# Image 11 downloaded and saved as image_10.jpg
# ...
# Image 12 downloaded and saved as image_11.jpg
# ...
# Image 13 downloaded and saved as image_12.jpg
# ...
# Image 14 downloaded and saved as image_13.jpg
# ...
# Image 15 downloaded and saved as image_14.jpg
# ...
# Image 16 downloaded and saved as image_15.jpg
# ...
# Image 17 downloaded and saved as image_16.jpg
# ...
# Image 18 downloaded and saved as image_17.jpg
# ...
# Image 19 downloaded and saved as image_18.jpg
# ...
# Image 20 downloaded and saved as image_19.jpg
# ...
# Image 21 downloaded and saved as image_20.jpg
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By  # Import By
import requests
import os
import time

# Provide the path to your ChromeDriver executable
chrome_driver_path = "./chromedriver.exe"  # Update this with your actual path

# Setup Selenium using the Service class
service = Service(executable_path=chrome_driver_path)
driver = webdriver.Chrome(service=service)

# Navigate to the website
driver.get('https://www.google.com/search?rlz=1C1CHBF_enIN916IN916&sca_esv=18fa2256dcc18326&sca_upv=1&cs=0&sxsrf=ADLYWIK6jFd-IU5LknMfK7l8r0YttPNuow:1727384639855&q=michelle+obama&udm=2&fbs=AEQNm0AeMNWKf4PpcKMI-eSa16lJtzWU9eQI5j4O99Tsc1uZNYkkC4AT6rNaDqRupTftK_KcOXQL423HVCOC1AAWB6dUmPGSLOwXZbDndU7i1bTAPZCseLZdJ6Cg5KNra36T7aP9rNtHwc-KPqHkwOKX_IiJEsocZntRO4x5TYWlwPYckDQdVaQLfvaFN-NFWayCHWy2Bg2zVGX8uwxU4pCPm4amfrcI_A&sa=X&ved=2ahUKEwiVjOWeweGIAxU1ZWwGHSSODrYQtKgLegQIBxAB&biw=1280&bih=551&dpr=1.5')

# Specify the directory to save images
save_directory = "./dataset/michelle_obama"  # Change this to your desired directory
os.makedirs(save_directory, exist_ok=True)  # Create directory if it doesn't exist

# Download images, limited to 50
downloaded_images = 0  # Keep track of downloaded images
img_urls_set = set()  # Use a set to avoid duplicates

while downloaded_images < 100:
    # Extract image URLs
    images = driver.find_elements(By.TAG_NAME, 'img')
    img_urls = [img.get_attribute('src') for img in images if img.get_attribute('src')]

    # Filter out invalid or None URLs and add them to the set
    for url in img_urls:
        if url.startswith('http') and url not in img_urls_set:
            img_urls_set.add(url)
            downloaded_images += 1
            print(f"Downloading image {downloaded_images} from {url}...")  # Print status
            try:
                img_data = requests.get(url).content
                with open(os.path.join(save_directory, f'image_{downloaded_images}.jpg'), 'wb') as img_file:
                    img_file.write(img_data)
                print(f"Image {downloaded_images} downloaded and saved as image_{downloaded_images}.jpg")  # Success message
            except Exception as e:
                print(f"Failed to download image {downloaded_images}: {e}")
            
            if downloaded_images >= 50:
                break

    # Scroll down to load more images
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Wait for new images to load

# Quit the browser
driver.quit()
# Out:
# ...
# Image 1 downloaded and saved as image_1.jpg
# ...
# Image 2 downloaded and saved as image_2.jpg
# ...
# Image 3 downloaded and saved as image_3.jpg
# ...
# Image 4 downloaded and saved as image_4.jpg
# ...
# Image 5 downloaded and saved as image_5.jpg
# ...
# Image 6 downloaded and saved as image_6.jpg
# ...
# Image 7 downloaded and saved as image_7.jpg
# ...
# Image 8 downloaded and saved as image_8.jpg
# ...
# Image 9 downloaded and saved as image_9.jpg
# ...
# Image 10 downloaded and saved as image_10.jpg
# ...
# Image 11 downloaded and saved as image_11.jpg
# ...
# Image 12 downloaded and saved as image_12.jpg
# ...
# Image 13 downloaded and saved as image_13.jpg
# ...
# Image 14 downloaded and saved as image_14.jpg
# ...
# Image 15 downloaded and saved as image_15.jpg
# ...
# Image 16 downloaded and saved as image_16.jpg
# ...
# Image 17 downloaded and saved as image_17.jpg
# ...
# Image 18 downloaded and saved as image_18.jpg
# ...
# Image 19 downloaded and saved as image_19.jpg
# ...
# Image 20 downloaded and saved as image_20.jpg
# ...
# Image 21 downloaded and saved as image_21.jpg
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By  # Import By
import requests
import os
import time

# Provide the path to your ChromeDriver executable
chrome_driver_path = "./chromedriver.exe"  # Update this with your actual path

# Setup Selenium using the Service class
service = Service(executable_path=chrome_driver_path)
driver = webdriver.Chrome(service=service)

# Navigate to the website
driver.get('https://www.google.com/search?q=pv+sindhu&rlz=1C1CHBF_enIN916IN916&sca_esv=18fa2256dcc18326&sca_upv=1&cs=0&udm=2&biw=1280&bih=551&sxsrf=ADLYWIKKo6QxrmBokt0aP9gRdHKqxJ3HHg%3A1727384642321&ei=Qsz1ZoWpE_mOnesP-PST8Aw&oq=&gs_lp=Egxnd3Mtd2l6LXNlcnAiACoCCAAyBxAjGCcY6gIyBxAjGCcY6gIyBxAjGCcY6gIyBxAjGCcY6gIyBxAjGCcY6gIyBxAjGCcY6gIyBxAjGCcY6gIyBxAjGCcY6gIyBxAjGCcY6gIyBxAjGCcY6gJI1wlQAFgAcAF4AJABAJgBAKABAKoBALgBA8gBAPgBAZgCAaACOKgCCpgDOJIHATGgBwA&sclient=gws-wiz-serp')

# Specify the directory to save images
save_directory = "./dataset/pv_sindhu"  # Change this to your desired directory
os.makedirs(save_directory, exist_ok=True)  # Create directory if it doesn't exist

# Download images, limited to 50
downloaded_images = 0  # Keep track of downloaded images
img_urls_set = set()  # Use a set to avoid duplicates

while downloaded_images < 200:
    # Extract image URLs
    images = driver.find_elements(By.TAG_NAME, 'img')
    img_urls = [img.get_attribute('src') for img in images if img.get_attribute('src')]

    # Filter out invalid or None URLs and add them to the set
    for url in img_urls:
        if url.startswith('http') and url not in img_urls_set:
            img_urls_set.add(url)
            downloaded_images += 1
            print(f"Downloading image {downloaded_images} from {url}...")  # Print status
            try:
                img_data = requests.get(url).content
                with open(os.path.join(save_directory, f'image_{downloaded_images}.jpg'), 'wb') as img_file:
                    img_file.write(img_data)
                print(f"Image {downloaded_images} downloaded and saved as image_{downloaded_images}.jpg")  # Success message
            except Exception as e:
                print(f"Failed to download image {downloaded_images}: {e}")
            
            if downloaded_images >= 100:
                break

    # Scroll down to load more images
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Wait for new images to load

# Quit the browser
driver.quit()
# Out:
# ...
# Image 1 downloaded and saved as image_1.jpg
# ...
# Image 2 downloaded and saved as image_2.jpg
# ...
# Image 3 downloaded and saved as image_3.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 29
#      26 while downloaded_images < 200:
#      27     # Extract image URLs
#      28     images = driver.find_elements(By.TAG_NAME, 'img')
# ---> 29     img_urls = [img.get_attribute('src') for img in images if img.get_attribute('src')]
#      31     # Filter out invalid or None URLs and add them to the set
#      32     for url in img_urls:
#
# Cell In[4], line 29, in <listcomp>(.0)
#      26 while downloaded_images < 200:
#      27     # Extract image URLs
#      28     images = driver.find_elements(By.TAG_NAME, 'img')
# ---> 29     img_urls = [img.get_attribute('src') for img in images if img.get_attribute('src')]
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By  # Import By
import requests
import os
import time

# Provide the path to your ChromeDriver executable
chrome_driver_path = "./chromedriver.exe"  # Update this with your actual path

# Setup Selenium using the Service class
service = Service(executable_path=chrome_driver_path)
driver = webdriver.Chrome(service=service)

# Navigate to the website
driver.get('')

# Specify the directory to save images
save_directory = "./dataset/ratan_tata"  # Change this to your desired directory
os.makedirs(save_directory, exist_ok=True)  # Create directory if it doesn't exist

# Download images, limited to 50
downloaded_images = 0  # Keep track of downloaded images
img_urls_set = set()  # Use a set to avoid duplicates

while downloaded_images < 100:
    # Extract image URLs
    images = driver.find_elements(By.TAG_NAME, 'img')
    img_urls = [img.get_attribute('src') for img in images if img.get_attribute('src')]

    # Filter out invalid or None URLs and add them to the set
    for url in img_urls:
        if url.startswith('http') and url not in img_urls_set:
            img_urls_set.add(url)
            downloaded_images += 1
            print(f"Downloading image {downloaded_images} from {url}...")  # Print status
            try:
                img_data = requests.get(url).content
                with open(os.path.join(save_directory, f'image_{downloaded_images}.jpg'), 'wb') as img_file:
                    img_file.write(img_data)
                print(f"Image {downloaded_images} downloaded and saved as image_{downloaded_images}.jpg")  # Success message
            except Exception as e:
                print(f"Failed to download image {downloaded_images}: {e}")
            
            if downloaded_images >= 100:
                break

    # Scroll down to load more images
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Wait for new images to load

# Quit the browser
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import requests
import os
import time

# Provide the path to your ChromeDriver executable
chrome_driver_path = "./chromedriver.exe"  # Update this with your actual path

# Setup Selenium using the Service class
service = Service(executable_path=chrome_driver_path)
driver = webdriver.Chrome(service=service)

# Navigate to the website
driver.get('https://www.google.com/search?q=ratan+tata+images&rlz=1C1CHBF_enIN916IN916&sca_esv=18fa2256dcc18326&sca_upv=1&cs=0&udm=2&biw=1280&bih=551&sxsrf=ADLYWIKZkFGR54bhCVId6HNS0RrbQcoikg%3A1727384755011&ei=s8z1Zsw0zJax4w_crsDBCA&oq=ratan+&gs_lp=&sclient=gws-wiz-serp')

# Specify the directory to save images
save_directory = "./dataset/ratan_tata"  # Change this to your desired directory
os.makedirs(save_directory, exist_ok=True)  # Create directory if it doesn't exist

# Download images, limited to 100
downloaded_images = 0  # Keep track of downloaded images
img_urls_set = set()  # Use a set to avoid duplicates

while downloaded_images < 100:
    # Extract images
    for img in driver.find_elements(By.TAG_NAME, 'img'):
        # Get image dimensions
        width = img.get_attribute('width')
        height = img.get_attribute('height')
        
        # Convert width and height to integers if they are not None
        if width and height:
            width = int(width)
            height = int(height)
            
            # Filter out small images (e.g., logos might be smaller than 100x100)
            if width > 100 and height > 100:
                img_url = img.get_attribute('src')
                
                # Ensure the image URL is valid and not already downloaded
                if img_url and img_url.startswith('http') and img_url not in img_urls_set:
                    img_urls_set.add(img_url)
                    downloaded_images += 1
                    print(f"Downloading image {downloaded_images} from {img_url}...")
                    
                    try:
                        img_data = requests.get(img_url).content
                        with open(os.path.join(save_directory, f'image_{downloaded_images}.jpg'), 'wb') as img_file:
                            img_file.write(img_data)
                        print(f"Image {downloaded_images} downloaded and saved as image_{downloaded_images}.jpg")
                    except Exception as e:
                        print(f"Failed to download image {downloaded_images}: {e}")
                        
                if downloaded_images >= 100:
                    break

    # Scroll down to load more images
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Wait for new images to load

# Quit the browser
driver.quit()
# Out:
# ...
# Image 1 downloaded and saved as image_1.jpg
# ...
# Image 2 downloaded and saved as image_2.jpg
# ...
# Image 3 downloaded and saved as image_3.jpg
# ...
# Image 4 downloaded and saved as image_4.jpg
# ...
# Image 5 downloaded and saved as image_5.jpg
# ...
# Image 6 downloaded and saved as image_6.jpg
# ...
# Image 7 downloaded and saved as image_7.jpg
# ...
# Image 8 downloaded and saved as image_8.jpg
# ...
# Image 9 downloaded and saved as image_9.jpg
# ...
# Image 10 downloaded and saved as image_10.jpg
# ...
# Image 11 downloaded and saved as image_11.jpg
# ...
# Image 12 downloaded and saved as image_12.jpg
# ...
# Image 13 downloaded and saved as image_13.jpg
# ...
# Image 14 downloaded and saved as image_14.jpg
# ...
# Image 15 downloaded and saved as image_15.jpg
# ...
# Image 16 downloaded and saved as image_16.jpg
# ...
# Image 17 downloaded and saved as image_17.jpg
# ...
# Image 18 downloaded and saved as image_18.jpg
# ...
# Image 19 downloaded and saved as image_19.jpg
# ...
# Image 20 downloaded and saved as image_20.jpg
# ...
# Image 21 downloaded and saved as image_21.jpg
# ...
